# %%
# snake,water,gun game

import random
# number of wins for computer are x
x=0
# number of wins for vinay are y
y=0
list=["s","w","g"]
# number of chances  are n
n=10
for i in range(1,n+1):
    # choice of computer is c
    c=random.choice(list)
    ''' choice of vinay is yc
    input 's' for snake,'w' for water and 'g' for gun
    '''

    yc=input()


    if c == yc:
       x = x + 0
       y = y + 0
       print('noone scored\n')

    elif c == 's' and yc == 'w':
            x = x + 0
            y = y + 1
            print('vinay scores 1\n')

    elif c == 's' and yc == 'g':
            x = x + 0
            y = y + 1
            print('vinay scores 1\n')

    elif c == 'w' and yc == 's':
            x = x + 1
            y = y + 0
            print('computer scores 1\n')

    elif c == 'w' and yc == 'g':
            x = x + 1
            y = y + 0
            print('computer scores 1\n')

    elif c == 'g' and yc == 's':
            x = x + 1
            y = y + 0
            print('computer scores 1\n')

    elif c=='g' and yc=='w':
            x = x + 0
            y = y + 1
            print('vinay scores 1\n')

    else:
        print('invalid choice')

print(f'computer score is {x} and your score is {y}\n' )
if x > y:
        print('you lose')
else:
    if x < y:
        print('you won')
    else:
        print(' tie ')
